# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path

# %%
figdir = Path('../figures')
figdir.mkdir(exist_ok=True)

# %%
rng = np.random.default_rng(0)

# %%
dat = rng.random((100,2))

# %%
g = sns.jointplot(x=dat[:, 0], y=dat[:, 1], )
